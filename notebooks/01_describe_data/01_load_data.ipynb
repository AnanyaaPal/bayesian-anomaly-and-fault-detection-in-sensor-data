# %%
import pandas as pd
import scipy

import path
from path import Path

# %% [markdown]
# ## 1 Load Data

# %%
dir_root = Path.cwd().parent.parent

dir_train = dir_root / "data" / "train"
dir_train
# Out:
# Path('/Users/AnanyaPal1/Documents/TUD/5th semester/monte carlo simulations/bayesian-anomaly-and-fault-detection-in-sensor-data/data/train')

# %%
train_data = pd.read_csv(dir_train / "X_train.txt", 
                         sep='\\s+',
                         header=None)
train_data.shape
# Out:
# (7352, 561)

# %%
type(train_data)
# Out:
# pandas.core.frame.DataFrame

# %%
train_data.head(1)
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
#
#         7         8         9    ...       551       552       553       554  \
# 0 -0.983185 -0.923527 -0.934724  ... -0.074323 -0.298676 -0.710304 -0.112754
#
#       555       556       557       558       559       560
# 0  0.0304 -0.464761 -0.018446 -0.841247  0.179941 -0.058627
#
# [1 rows x 561 columns]

# %% [markdown]
# Load the activity label file for D_train.

# %%
train_labels = pd.read_csv(dir_train / "y_train.txt", header=None, index_col=None)
print(len(train_labels))
# Out:
# 7352

# %%
type(train_labels)
# Out:
# pandas.core.frame.DataFrame

# %%
train_labels.head(1)
# Out:
#    0
# 0  5
